# %%
"""
1. Write a Python program to find words which are greater than given length k?

Ans:

def str_gr(k, str):
    str1 = []
    sen = str.split(" ")
    for i in sen:
        if len(i) >= k:
            str1.append(i)
    
    return str1

k = int(input("Enter number: "))
str = input("Enter any text: ")
print(str_gr(k, str))
    
    

"""

# %%
"""
2. Write a Python program for removing i-th character from a string?

Ans:

def rmv(i, str):
    x = str[:i]
    y = str[i+1:]
    
    return x+y
i = 1
str = "Hello"
print(rmv(i,str)
      
      OR
      
def rmv(i, str):
    for x in range(len(str)):
        if x == i:
            str = str.replace(str[i],"")
    return str
i = 1
str = "Hello"
print(rmv(i,str))
"""

# %%
"""
3. Write a Python program to split and join a string?

Ans:
str = "hello how are you"
s = str.split()
t = ''.join(s)
print("after spliting :",s)
print("after joining:",t)

"""

# %%
"""
4. Write a Python to check if a given string is binary string or not?

Ans:

def check(str):
    t = '01'
    count = 0
    for char in str:
        if char not in t:
            count = 1
            break
        else:
            pass
    if count:
         print('No')
    else:
         print('yes')
            
            
str = '1001'
check(str)


"""

# %%
"""
5. Write a Python program to find uncommon words from two Strings?

Ans:
def uncmn(x,y):
    list_x = x.split()
    list_y = y.split()
    nc = ''
    for i in list_x:
        if i not in list_y:
            nc = nc + ' ' + i
    for j in list_y:
        if j not in list_x:
            nc = nc + ' ' + j
    return nc

x = "Nikita Niraj Krishna"
y = "Nikita krishna Aditya"
print(uncmn(x,y))
    

"""

# %%
"""
6. Write a Python to find all duplicate characters in string?

Ans:
s = 'shivani'
char = []
for i in s:
    if i not in char:
        char.append(i)
    else:
        print(f"{i} is ocurring more than once")

"""

# %%
"""
7. Write a Python Program to check if a string contains any special character?

Ans:
x = input()
x.split()
c = 0
s = "[@_!#$%^&*()<>?/\|}{~:]"
for i in range(len(x)):
    if x[i] in s:
        c+=1
if (c>0):
    print("String contains a special character")
else:
    print("String do not contains a special character")

"""
